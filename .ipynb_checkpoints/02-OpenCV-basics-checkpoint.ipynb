# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
plt.imshow(img)

# %%
# MATPLOTLIB --> RGB in this order
# OpenCV --> BGR in this order

# %%
# Color conversion
fix_img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fix_img)

# %%
img_gray = cv2.imread('DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_gray.shape
# Out:
# (1300, 1950)

# %%
plt.imshow(img_gray)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
plt.imshow(fix_img)

# %%
fix_img.shape
# Out:
# (1300, 1950, 3)

# %%
new = cv2.resize(fix_img,(1000,400))

# %%
plt.imshow(new)

# %%
w_ratio = 0.9
h_ratio = 0.2
new_img = cv2.resize(fix_img,(0,0),fix_img,w_ratio,h_ratio)
plt.imshow(new_img)

# %%
n = cv2.flip(fix_img,-1)
plt.imshow(n)

# %%
type(fix_img)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('new-puppy.jpg',fix_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(8,8))
ax = fig.add_subplot(111)
ax.imshow(fix_img)
